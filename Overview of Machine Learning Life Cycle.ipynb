# %% [markdown]
# ## Building Machine Learning Pipelines: Data Analysis Phase
#
# In this and the upcoming videos we will focus on creating Machine Learning Pipelines considering all the life cycle of a Data Science Projects. This will be important for professionals who have not worked with huge dataset.

# %% [markdown]
# ![6.PNG](attachment:6.PNG)

# %% [markdown]
# ## Training Step (Main.py)
# ## Route 1 : Training
# ### Step 1 : Data Validation
# * #### Read Data from Client
# * #### Data Validation (FileName, Number_of_Columns ,Missing_Whole_Column)
# * #### Transform the Data According to DataBase Requirement(fill Nan with 'Null')
# * #### Insert Data into DataBase
# * #### Export Data to CSV
#
# ### Step 2 : Model Training
# * #### Read Data From Exported CSV file
# * #### Data Pre-Processing (Missing values , Categorical values etc)
# * #### Form different cluster according to the Data
# * #### Find Model for each Cluster
# * #### Model Tuning
# * #### Deploy Model
#
# ## Route 1 : Prediction
# ### Step 1 : Data Validation
# * #### Read Data from Client
# * #### Data Validation (FileName, Number_of_Columns ,Missing_Whole_Column)
# * #### Transform the Data According to DataBase Requirement(fill Nan with 'Null')
# * #### Insert Data into DataBase
# * #### Export Data to CSV
#
# ### Step 2 : Prediction
# * Load the Models and predict

# %% [markdown]
# # All the Lifecycle In A Data Science Projects
# * ## 1. Data Analysis
# * ## 2. Feature Engineering
# * ## 3. Feature Selection
# * ## 4. Model Building
# * ## 5. Model Deployment

# %% [markdown]
# # Data Collection Strategy  :
# * ### From company , 3rd party API's , Surveys

# %% [markdown]
# # 1. Data Analysis :
# * ## 1. Check for Missing Values
# > ###  Find the Relationship between the Missing values and Target Variable (Using groupby(feature)[Target_Variable] , median , BAR PLOT  )
# * ## 2. Check for Numerical Variables
# > ### Temporal Variables (Date , time , Year etc)
# >> ### Plot the Relationship between Temporal Variables and Target using SCATTER PLOT
# > ###  Discrete Variables
# >> ### Plot the Relationship between Discrete Variables and Target by using BAR Plots (Using groupby(feature)[Target_Variable] , median , BAR PLOT  )
# > ###  Continuous Variables
# >> ### Plot the Relationship between Continuous Variables and Target by using Distribution Plots (HIST or KDE)
# >> ### If the above Distribution Plots for Continuous Variables doesn't follow Gaussian or Normal Distribution , then Apply TRASFORMATIONS (like log-normal , box-cox)
# >> ### After TRASFORMATION Plot the Relationship between Continuous Variables and Target by using SCATTER PLOT
# * ## 3. Outliers
# > # boxplot
# > ## This is Used only for CONTINUOUS Variables
# >> ### NOT FOR CATEGORICAL VARIABLES
# * ## 4. Categorical Variables
# > ## Check Cardinality or Unique Values in Categorical Features
# > ## Find out the relationship between categorical variable and Target using BAR Plots (Using groupby(feature)[Target_Variable] , median , BAR PLOT  )

# %% [markdown]
# #  2. Feature Engineering
# * ## 1. Train Test Split
# > ### Apply Feature Engineering for the Training data and apply same Feature Engineering for the Test Data , Inorder to avoid DATA LEAKAGE in the Real World Problems
#
# * ## 2. Handling  Missing Values
#
# > ### Handling  Missing Values for Categorical Variables
# >> ### Replace The missing Values with New Label (Ex : 'Missing')
#
# > ### Handling  Missing Values for Numerical Variables
# >> ### Create a New Column and Replace Nan With 1 otherwise 0 (To get more meaningful information)
# >> ### Replace The missing Values with Median
#
# > ### Handling Temporal Variables (Date Time Variables)
#
# * ## 3.  Convert Skewed Distribution into log-Normal Distribution , by applying log Transformation
# > ### Since the numerical variables are skewed we will perform log normal distribution (Only for those Numerical Continuous Variables which Skewed)
#
# * ## 4. Handling Rare Categorical Feature
#
# > ### If the count of the Categorical Features is greater that x \% [Ex : 1\% or 5\% ]then take it as it is , otherwise convert it into a New Label ("Rare_Var")
#
# * ## 5. Convert Categorical Features into Numerical Features by applying Encoding
#
# * ## 6.  Feature Scaling (Ex: Standardization or Normalization)
# > ### Apply Feature Scaling for all Columns Except Target Variable
#
# * ## 7. At last Save the DataFrame into CSV file
# * ## 8. Do the Same Feature Engineering Steps for Test Data

# %% [markdown]
# ## Why are  Missing values Exists??
# Survey--Depression Survey
# 1. They hesitate to put down the information
# 2. Survey informations are not that valid
# 3. Men--salary
# 4. Women---age
# 5. People may have died----NAN
#
# Data Science Projects---Dataset should be collected from multiple sources
#
# ## What are the different types of Missing Data?
#
# * ### Type 1. Missing Completely at Random  (MCAR):
# A variable is missing completely at random (MCAR) if the probability of being missing is the same for all the observations. When data is MCAR, there is absolutely no relationship between the data missing and any other values, observed or missing, within the dataset. In other words, those missing data points are a random subset of the data. There is nothing systematic going on that makes some data more likely to be missing than other.
#
# * ### Type 2. Missing Data Not At Random(MNAR): Systematic missing Values
# There is absolutely some relationship between the data missing and any other values, observed or missing, within the dataset.
#
# * ### Type-3 Missing At Random(MAR)
# #### Men---hide their salary
# #### Women---hide their age
#
# # Handling Missing Values :
#
# * ### 1. Delete Rows
# > #### DisAdv : Loose of Data
#
# * ### 2. Mean/ Median/Mode replacement
# > #### When should we apply?
# > * Mean/median imputation has the assumption that the data are missing completely at random(MCAR). We solve this by replacing the NAN with the most frequent occurance of the variables
# > *  ### Advantages
# > 1. Easy to implement(Robust to outliers)
#  > 2. Faster way to obtain the complete dataset
# > * ### Disadvantages
# > 1. Change or Distortion in the original variance
# > 2. Impacts Correlation
#
# * ### 3. Random Sample Imputation
# > #### Aim: Random sample imputation consists of taking random observation from the dataset and we use this observation to replace the nan values
# > * ### When should it be used?
# > It assumes that the data are missing completely at random(MCAR)
# > *  ### Advantages
# > 1. Easy To implement
# > 2. There is less distortion in variance
# > * ### Disadvantages
# > 1. In Every situation randomness wont work
#
# * ### 4. Capturing NAN values with a new feature
# > #### It works well if the data are not missing completely at random (MNAR)
# > #### Create a new Column and where ever the values are Nan Then insert 1 orelse 0
# > #### Replace the Nan Values in the already existing Column with Median(In case of Numerical Values) or Mode(In case of Categorical Values)
# > *  ### Advantages
# > 1. Easy to implement
# > 2. Captures the importance of missing values
# > * ### Disadvantages
# > 1. Creating Additional Features(Curse of Dimensionality)
#
# * ### 5. End of Distribution imputation
# > #### Create a New Column and Replace the Nan with a value from the End Of the Distribution
# > #### Replace the Nan Values in the already existing Column with Median
#
# * ### 6. Arbitrary imputation
# > #### Replacing NAN by an arbitrary value
# > *  ### Advantages
# >1. Easy to implement
# >2. Captures the importance of missingess if there is one
# > * ### Disadvantages
# >1. Distorts the original distribution of the variable
# >2. If missingess is not important, it may mask the predictive power of the original variable by distorting its distribution
# >3.  Hard to decide which value to use
#
# * ### 7. Frequent categories imputation
# > ### To Handle Categroical Missing Values
# > *  ### Advantages
# >1. Easy To implement
# > 2. Fater way to implement
# > * ### Disadvantages
# >1. Imbalanced Data within the Categories
# >2. Since we are using the more frequent labels, it may use them in an over respresented way, if there are many nan's
# >3. It distorts the relation of the most frequent label
#
#
# * ### 8. Apply Classifer Algorithm To find Missing Values
# > #### Missing Column : Target , Other_Columns : Input
# * ### 9. Unsupervised ML
#
# ## -----------------------------
# * ### 10. Suppose if We have more More Nan categories, we just replace NAN with a new category
# > ### To Handle Categroical Missing Values
# * ### 11. KNN imputation

# %% [markdown]
# ## Median Imputation
# ![1.PNG](attachment:1.PNG)

# %% [markdown]
# ## Random Sample Imputation
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# ## End of Distribution Imputation
# ![3.PNG](attachment:3.PNG)

# %% [markdown]
# # Handling Categorical Varialbles :
# https://www.youtube.com/watch?v=uWD-r7GZppg&list=PLZoTAELRMXVPwYGE2PXD3x0bfKnR0cJjN&index=10
#
# https://www.youtube.com/watch?v=OTPz5plKb40&list=PLZoTAELRMXVPwYGE2PXD3x0bfKnR0cJjN&index=2
# * ## 1. Nominal Encoding :
#
# > ### a. One Hot Encoding
# > * #### Number of Columns Created is equal to Number of Categories
# > * #### DisAdv : Number of Columns Increases as Categories Increases
#
# > ### b. One Hot Encoding with Many Categorical Variables
# >* ### Apply One Hot Encoding to Top Categories
#
# > ### c. Mean Encoding
#
# > ### d. Count of Frequency Encoding
# > * ### Advantages
# >1. Easy To Use
# >2. Not increasing feature space
# > * ###  Disadvantages
# >1. It will provide same weight if the frequencies are same
#
# > ### e. Probability Ratio Encoding
#
# * ## 2. Ordinal Encoding :
#
# > ### a. Label Encoding
# > ### b. Target Guided Ordinal Encoding
# > * ###  Ordering the labels according to the target
# > * ###  Replace the labels by the joint probability of being 1 or 0
# > * ### If two Categories have same count , then we may Loose Information

# %% [markdown]
# # Feature Scaling :
#
# ###  Ques : For What algos we need to apply Feature Scaling ?
# ### Ans :
# * ### For the Algos where ever we have Gradient Descent or Finding Distance
# ** ### Ex : Linear Regression , Logistic Regression, K-Means , KNN , Hierarchial Clustering , Deep Learning Techniques like ANN , CNN , RNN
#
# ###  Ques : For What algos we  should NOT apply Feature Scaling ?
# ### Ans :
# * ### Ex : Decision Tree , Random Forests , XGboost , ENsemble Techiques
#
# ## Types Of Transformation
# * ### 1. Normalization And Standardization
# > #### Standardization :: Mean = 0 , Variance = 1
# > #### Normalization :: Value lies between 0 and 1
# * ### 2. Scaling to Minimum And Maximum values
# * ### 3. Robust Scaler
# > ### Scaling To Median And Quantiles
# > ### More RObust to Outlier
# > ### IQR = 75th quantile - 25th quantile
# > ### X_scaled = (X - X.median) / IQR
#
# * ### 4. Guassian or Normal Transformation
# ** Some machine learning algorithms like linear and logistic assume that the features are normally distributed
# ** Accuracy
# ** Performance
# > * ###  Logarithmic Transformation
# > * ###    Reciprocal Transformation
# > * ###    Square Root Transformation
# > * ###    Exponential Transformation
# > * ###    Box Cox Transformation

# %% [markdown]
# The Box-Cox transformation is defined as:
#
# T(Y)=(Y exp(λ)−1)/λ
#
# where Y is the response variable and λ is the transformation parameter. λ varies from -5 to 5. In the transformation, all values of λ  are considered and the optimal value for a given variable is selected.

# %% [markdown]
# # Handling Imbalanced Dataset
# ### 1. Ensemble Techniques or Try with Different Algorithms
# * #### KFold Cross Validation ,  GridSearchCV and Hyper Parameter Tuning
#
# ### 2. Under Sampling
# * #### Reduces the Points of Maximum Labels
# * #### Use NearMiss from imblearn Package
# * #### DisAdv :: Loss of Data
# * #### Use under Sampling only when there is Less Imbalance
#
# ### 3. Over Sampling
# * #### Increases the Points of Minimum Labels
# * #### Use RandomOverSampler from imblearn Package
# * #### Use Over Sampling only when there is Huge Imbalance
#
# ### 4. SMOTETomek
# ### SMOTE :: Synthetic Minority OverSampling Technique
# * #### It Generates the Synthetic Data Points By taking the Average of the Nearest Neighbours of Minority Class
# * #### Use SMOTETomek from imblearn Package

# %% [markdown]
# # Outliers
# ### Which Machine Learning Models Are Sensitive To Outliers?
# * ### 1. Naivye Bayes Classifier--- Not Sensitive To Outliers
# * ### 2. SVM--------                Not Sensitive To Outliers
# * ### 3. Linear Regression----------  Sensitive To Outliers
# * ### 4. Logistic Regression-------   Sensitive To Outliers
# * ### 5. Decision Tree Regressor or Classifier---- Not Sensitive
# * ### 6. Ensemble(RF,XGboost,GB)------- Not Sensitive
# * ### 7. KNN--------------------------- Not Sensitive
# * ### 8. Kmeans------------------------ Sensitive
# * ### 9. Hierarichal------------------- Sensitive
# * ### 10. PCA-------------------------- Very Very Sensitive
# * ### 11. Neural Networks-------------- Sensitive

# %% [markdown]
# ## For Gaussian Distribution
# ![4.png](attachment:4.png)
#
# ### uppper_boundary=df[Column_Name].mean() + 3* df[Column_Name].std()
# ### lower_boundary=df[Column_Name].mean() - 3* df[Column_Name].std()

# %% [markdown]
# ## For Other Distributions
# ### IQR=df.Column_Name.quantile(0.75)-df.Column_Name.quantile(0.25)
# ### lower_bridge=df[Column_Name].quantile(0.25)-(1.5 * IQR)
# ### upper_bridge=df[Column_Name].quantile(0.75)+(1.5 * IQR)
#
# ## For Extreme Outliers
# ### IQR=df.Column_Name.quantile(0.75)-df.Column_Name.quantile(0.25)
# ### lower_bridge=df[Column_Name].quantile(0.25)-(3 * IQR)
# ### upper_bridge=df[Column_Name].quantile(0.75)+(3 * IQR)

# %% [markdown]
# ## Remove Outlier :
# ### data.loc[data[Column_Name]>=uppper_boundary,Column_Name]=uppper_boundary
# ### data.loc[data[Column_Name]<=lower_boundary,Column_Name]=lower_boundary

# %% [markdown]
# # 3. Feature Selection :
# > ### By using PCA or SelectFromModel or t-SNE etc for dimensionality Reduction

# %% [markdown]
# # 4. Model Building
#
# * ## Classification and Regression :: Supervised Learning
# * ## Clustering and Association :: Unsupervised Learning

# %% [markdown]
# > # Supervised Learning
#
# # 01 Linear Regression Algorithm:
#
# * ## 1. Cost Function and Optimization:
# > ### Mean Square Error MSE  :: Gradient Ascent
#
# * ## 2. Performance Measure :
# > ## P-value , R-Squared and Adjusted R-Squared
#
# ## Linear Regression Programming :
# * ### Read , Describe and Find Null values and Replace Null Values in the Dataset
# * ### Handle Categorical Values [get_dummies , One_Hot encoder , Label Encoder , Word2Vec]
# * ### Descriptive Statistics to find Relations (Plots)
# * ### Inferential Statistics (P_value , R_Squared and Adjusted R_Squared ) to find the Relations
# * ### Check Multi Collinearity using Variance Inflation Factor (VIF)
# * ###  Feature Scaling (Standardaization or Normalization )
# * ### Train Test Split , Model Fit , Model_predict
# * ### Check for Overfitting : Check Accuray of Traing data and Accuracy of Test data
# * ### Incase of Over fitting : Apply Regularization Techniques Lasso Regression , Ridge Regression , Elasticnet  Regression
# * ### Inferential Statistics (P_value , R_Squared and Adjusted R_Squared ) to find the Relations
# * ### Save the best Model in Pickle format
# * ### Deployment in cloud
#
# ### (*  Incase of Polynomial Regression Apply Poly_regresion.fit transform )

# %% [markdown]
# # 02 Logistic Regression Algorithm:
# * ## 1. Activation Function : Sigmoid
# * ## 2. Cost Function and Optimization:
# > ### Positive (LogLikelihood Loss Fn)  :: Gradient Ascent
# > ### Negative (Cross Entropy or Logistic Loss or Log Loss)   :: Gradient Descent
# * ## 3. Performance Measure :
# > ## Confusion Matrix , Accuracy , Recall OR Sensitivity , Precision , F1Score , Specificity
# * ## 4. To Choose Threshold : ROC (Receiver Operator Charecteristics)
# * ## 5. To Choose Best Algorithm : AUC (Area Under Curve)

# %% [markdown]
# # 03 Decision Tree Classifier and Regressor:
# * ## 1. Different Index : Entropy , Gini
# * ## 2. Find Entropy or Gini and Information Gain or Gain Ratio
# * ## 3. To avoid Over Fitting : Pruning (Pre and Post)
# * ## 4. Different Algorithms for Decision Tree
#     * ID3 (Iterative Dichotomiser)
#     * C4.5 : (successor of ID3)
#     * Classfication and Regression Tree(CART) :
#     * C5.0
#     * MARS (multivariate adaptive regression splines)
#     * Decision Stump
#     * M5
#     * CIT (Conditional Inference Tree)
#     * CHAID (CHi-squared Automatic Interaction Detector)
# * ## 5. Advantages of Decision Tree:
#
#    * It can be used for both Regression and Classification problems.
#    * Decision Trees are very easy to grasp as the rules of splitting is clearly mentioned.
#    * Complex decision tree models are very simple when visualized. It can be understood just by visualising.
#    * Scaling and normalization are not needed.
#
#
# * ## 6. Disadvantages of Decision Tree:
#
#    * A small change in data can cause instability in the model because of the greedy approach.
#    * Probability of overfitting is very high for Decision Trees.
#    * It takes more time to train a decision tree model than other classification algorithms.

# %% [markdown]
# # 04 Ensemble Techniques
# * ### Ensemble methods take multiple small models and combine their predictions to obtain a more powerful predictive power.
# * ### µ = (Z1 + Z2 + Z3+.......+ Zn)/n
#
# * ### variance(µ) = σ^2/n
#
# * ### So, the expected value remained ‘µ’ but variance decreases when we use average of all the predictors.ods take multiple small models and combine their predictions to obtain a more powerful predictive power.
#
# * ### This is why taking mean is preferred over using single predictors.
# * ### Ensemble techniques such as Bagging, Boosting, stacking etc.
#
# ## 01 Bagging :
# * ### Bagging is the type of ensemble technique in which a single training algorithm is used on different subsets of the training data where the subset sampling is done with replacement (bootstrap).
# * ### Pasting (Opposite to Bootstrapping) [sampling is done without replacement]
#
#
# ## Random Forests
# * ### Random Forests is the Bagging type of ensemble technique in which a single Decision Tree training algorithm is used on different subsets of the training data where the subset sampling is done with replacement (bootstrap).
#
# ## 02 Stacking (Stacked Generalization) [Series Ensemble Technique]
#
# * ### Stacking is a type of ensemble technique which combines the predictions of two or more Different models, also called base models, and use the combination as the input for a new model (meta-model) i.e. a new model is trained on the predictions of the base models.
#
# ## 03 Boosting
# * ### Boosting is an ensemble approach(meaning it involves several trees) that starts from a weaker decision and keeps on building the models such that the final prediction is the weighted sum of all the weaker decision-makers.
# * ### The weights are assigned based on the performance of an individual tree.
#
# ### 03-1 AdaBoost (Adaptive Boosting) :
# * ### 1. Ada Boost is an Ensemble Technique
# * ### 2. Weights to Data Points (More weight to misClassified , Less weight to correctly Classified)
# * ### 3. Weights to Models or CLassifiers
#
# ### 03-2 Gradient Boosted Trees
# * ### 1.Gradient Boosted Trees is a Ensemble Boosting Technique where the base Model is Decision Tree
# * ### 2. It finds the gradient of Loss function to Reduce the Error
# * ### 3. Hence it is Called as Gradient Boosted Trees
# * ### 4. different loss functions (regression, classification, risk modelling etc.)
#
# ### 03-3 XGBoost
# * ### 1. XGBoost = GradientBoostingTrees + Regularization (For Loss Function)
# * ### 2. Unlike the other tree-building algorithms, XGBoost doesn’t use entropy or Gini indices. Instead, it utilises gradient (the error term) and hessian for creating the trees. Hessian and similarity for a Regression problem is the number of residuals and for a classification problem .
#
# ### **The main advantages:**
# - out of the box feature of appropriate bias-variance trade-off,
# - great computation speed as it utilises parallel computing and cache optimization,
# - uses hardware optimization,
# - works well even if the features are correlated
# - robust even if there is noise for classification problem
# - the facility of early stopping
# - the package is evolving, i.e., new features are being added.

# %% [markdown]
# # 05 K Nearest Neighbours (Lazy Learning Algorithm)
# * ### K-nearest neighbors (KNN) is a type of supervised learning algorithm which is used for both regression and classification
# * ### Given a dataset with different classes, KNN tries to predict the correct class of test data by calculating the distance between the test data and all the training points.
# * ### It then selects the k points which are closest to the test data.
#
# ## Distance Metrics
# * ### Euclidean Distance
# * ### Haming Distance : Mostly used for categorical
# * ### Manhattan Distance or L1 Norm  : sum of the absolute differences
#
# ### Why KNN is Lazy Learning Algorithm ?
# * ### Eager learners ::
# ** Most of the algorithms like Bayesian classification, logistic regression, SVM etc., are called Eager learners. These algorithms generalize over the training set before receiving the test data i.e. they create a model based on the training data before receiving the test data and then do the prediction/classification on the test data.
# * ### Lazy Learners ::
# ** But this is not the case with the k-NN algorithm. It doesn’t create a generalized model for the training set but waits for the test data. Once test data is provided then only it starts generalizing the training data to classify the test data.
#
# ##  Weighted Nearest Neighbour
# ** In weighted k-NN, we assign weights to the k nearest neighbors.The weights are typically assigned on the basis of distance.
# Sometimes rest of data points are assigned a weight of 0 also. The main intuition is that the points in neighbor should have more weights than father points.
#
# # Choosing the value of k
# ![9.png](attachment:9.png)
#
# ## Different KNN algorithms
#
# * ### k-Dimensional Tree (kd tree)
# * ### Ball Tree
#
#
# ### Pros and Cons of k-NN Algorithm
#
# Pros:
# *	It can be used for both regression and classification problems.
# *	It is very simple and easy to implement.
# *	Mathematics behind the algorithm is easy to understand.
# *	There is no need to create model or do hyperparameter tuning.
# *   KNN doesn't make any assumption for the distribution of the given data.
# *   There is not much time cost in training phase.
#
# Cons:
# *	Finding the optimum value of ‘k’
# *	It takes a lot of time to compute the distance between each test sample and all training samples.
# *	Since the model is not saved beforehand in this algorithm (lazy learner), so every time one predicts a test value, it follows the same steps again and again.
# *	Since, we need to store the whole training set for every test set, it requires a lot of space.
# *	It is not suitable for high dimensional data.
# *   Expensive in testing phase

# %% [markdown]
# # 06 Navie Bayes
# ![3.PNG](attachment:3.PNG)

# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %% [markdown]
# > # Unsupervised
#
# # 01 k-means Clustering:
# * ### K-Means is a clustering approach in which the data is grouped into K distinct non-overlapping clusters based on their distances from the K centres.
# * ### The value of **K** needs to be specified first and then the algorithm assigns the points to exactly one cluster.
#
# ### Algorithm:
# 1. Randomly assign K centres.
# 2. Calculate the distance of all the points from all the K centres and allocate the points to cluster based on the shortest distance. The model’s _inertia_ is the mean squared distance between each instance and its closest centroid. The goal is to have a model with the lowes intertia.
# 3. Once all the points are assigned to clusters, recompute the centroids.
# 4. Repeat the steps 2 and 3 until the locations of the centroids stop changing and the cluster allocation of the points becomes constant.
#
# ### The Elbow-Method (To find the optimum number of clusters)
# * ### This method is based on the relationship between the within-cluster sum of squared distances(WCSS Or Inertia)
# * ### The point after which the graph between WCSS and the number of clusters becomes comparatively smother is termed as the elbow and the number of cluster at that point are the optimum number of clusters
# ![elbow.PNG](attachment:elbow.PNG)

# %% [markdown]
# ### Diadvantages of K-means:
# * ### Stops at Local Minima , because of Not Convex Cost Function
# * ### Sensitive to Outliers
# * ### Choosing Number of Clusters
#
# # 02 Hierarchical clustering :
#
# ### 1. Agglomerative (Bottom Up )
# > ### - Single Linkage: cluster distance = smallest pairwise distance
# > ### - Complete Linkage: cluster distance = largest pairwise distance
# > ### - Average Linkage: cluster distance = average pairwise distance
# > ### - Centroid Linkage: cluster distance=  distance between the centroids of the clusters
# > ### - Ward’s Linkage: cluster criteria= Minimize the variance in the cluster
#
#
# ### 2. Divisive (Top Down)
#
# ## Number of Clusters can be choosen by cutting Dendrogram
# ![3.PNG](attachment:3.PNG)

# %% [markdown]
# # 3 DBSCAN Clustering Algorithm
# * ### **Epsilon:**
#
#
# * ### **Min_points:**
#
# * ### **Core Points:**
#
# * ### **Border Points:**
#
# * ### **Noise:**
# ![point_def.PNG](attachment:point_def.PNG)

# %% [markdown]
# # Performance Measures for Clustering
# * # External Measures:
# > ### 1. Rand Index : It is Similar to Accuray in Classification Algorithms
# > ### 2.  Jaccard Coeeficient : It is similar to Rand index without DD (TN)
# > ### 3. Entropy of Cluster
# > ### 4. Purity  of Cluster
#
# ![4.PNG](attachment:4.PNG)

# %% [markdown]
# * # Internal Measures
# > ## 1 . Cohesion
# > ## 2 . Separation
# > ## 3 . Silhoeutte coefficient
#
# ![5.PNG](attachment:5.PNG)

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %% [markdown]
# # 04 Dimensionality Reduction Techinques:
# * ### Unsupervised Dimensionality Reduction method for Reducing the number of attributes in the data
# ### Why Dimensionality Reduction?
# * ###  High dimensional data impose computational efficiency challenges
# * ### Poor generalization (Fits well for Training data and could NOT generalize unseen test data) leads to overfitting
# ### Feature Selection
# * ### Selecting a small set of features from the given set of attributes
# * ### Examples : Variance Inflation Factor (VIF) [to find Multi collinearity]
# ### Feature Extraction
# * ### Creating a small set of features from the given set of attributes
# * ### Examples : PCA
#
#
# #  Principle Component Analysis (PCA)
# * ###  The principal component analysis is an unsupervised machine learning algorithm used for feature Extraction using dimensionality reduction techniques. As the name suggests, it finds out the principal components from the data. PCA transforms and fits the data from a higher-dimensional space to a new, lower-dimensional subspace This results into an entirely new coordinate system of the points where the first axis corresponds to the first principal component that explains the most variance in the data.
# * ###  Feature extraction method
#
# ### The projection theorem plays a central role in the formulation of these algorithms to Find uncorrelated attributes
#
# ### Ques : How to find the best subspace(K) or Best number of Columns?
# * ### Greater the variance of the projected data, less is the information loss due to projection
# * ### Explained Variance Ratio by SCREE plot
# ![scree.PNG](attachment:scree.PNG)
#
# ### Ques :  **What are the principal components?**
# * ### Principal components ( or Eigen vectors corresponding to Largest Eigen values ) are the derived features which explain the maximum variance in the data.
# * ### The first principal component explains the most variance, the 2nd a bit less and so on. Each of the new dimensions found using PCA is a linear combination of the old features.

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %% [markdown]
# > # **Pros of PCA:**
#
# - Correlated features are removed.
# - Model training time is reduced.
# - Overfitting is reduced.
# - Helps in better visualizations
# - Ability to handle noise
#
# > #  **Cons of PCA**
# - The resultant principal components are less interpretable than the original data
# - Can lead to information loss if the explained variance threshold is not considered appropriately.

# %% [markdown]
# # Cross-Validation (To Find the Hyper Parameters)
# ### *	Hold Out Method:  (Train : [ train , Validation ] ; Test , Repeat till 30 iters and find best model and combine train and validation build a final model)
# ### *	k-fold Cross-Validation : ( Divide the Dataset into K-Folds , Repeat k iterations such that 1 Fold for Test and Remaning Folds for Train  )
# ### * GridSearchCV

# %% [markdown]
# # Bias Variance Trade off
# * ## To find Number of Data Points or To find Complexity of Model
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# # 5. Deployment
